# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"RFM Customer Segmentation & Cohort Analysis Project"**. This is the first project of the Capstone Project Series, which consists of 3 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply **RFM Analysis** and Customer Segmentation using **K-Means Clustering**. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct **Cohort Analysis**.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
import pandas as pd
import numpy as np
import warnings

#visualizations
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

warnings.filterwarnings('ignore')

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
df = pd.read_excel("Online Retail.xlsx")

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1  536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 33.1+ MB

# %%
df1.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %% [markdown]
#  Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %%
df[['InvoiceNo','Quantity','UnitPrice']].corr()
# Out:
#            Quantity  UnitPrice
# Quantity   1.000000  -0.001235
# UnitPrice -0.001235   1.000000

# %%
sns.heatmap(df[['InvoiceNo','Quantity','UnitPrice']].corr(), annot=True, cmap="crest", linewidths=0.2, annot_kws={"size": 16});

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %%
df[['UnitPrice', 'Quantity']].describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='viridis')
# Out:
# <style type="text/css">
# #T_2514d_row0_col0, #T_2514d_row0_col1, #T_2514d_row0_col2, #T_2514d_row0_col5, #T_2514d_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_2514d_row1_col1, #T_2514d_row1_col2, #T_2514d_row1_col5 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_2514d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2514d_level0_row0" class="row_heading level0 row0" >UnitPrice</th>
#       <td id="T_2514d_row0_col0" class="data row0 col0" >541909.000000</td>
#       <td id="T_2514d_row0_col1" class="data row0 col1" >4.611114</td>
#       <td id="T_2514d_row0_col2" class="data row0 col2" >96.759853</td>
#       <td id="T_2514d_row0_col3" class="data row0 col3" >-11062.060000</td>
#       <td id="T_2514d_row0_col4" class="data row0 col4" >1.250000</td>
#       <td id="T_2514d_row0_col5" class="data row0 col5" >2.080000</td>
#       <td id="T_2514d_row0_col6" class="data row0 col6" >4.130000</td>
#       <td id="T_2514d_row0_col7" class="data row0 col7" >38970.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2514d_level0_row1" class="row_heading level0 row1" >Quantity</th>
#       <td id="T_2514d_row1_col0" class="data row1 col0" >541909.000000</td>
#       <td id="T_2514d_row1_col1" class="data row1 col1" >9.552250</td>
#       <td id="T_2514d_row1_col2" class="data row1 col2" >218.081158</td>
#       <td id="T_2514d_row1_col3" class="data row1 col3" >-80995.000000</td>
#       <td id="T_2514d_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_2514d_row1_col5" class="data row1 col5" >3.000000</td>
#       <td id="T_2514d_row1_col6" class="data row1 col6" >10.000000</td>
#       <td id="T_2514d_row1_col7" class="data row1 col7" >80995.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.Quantity.value_counts()
# Out:
#  1.0        148227
#  2.0         81829
#  12.0        61063
#  6.0         40868
#  4.0         38484
#              ...
# -472.0           1
# -161.0           1
# -1206.0          1
# -272.0           1
# -80995.0         1
# Name: Quantity, Length: 722, dtype: int64

# %%
df.Quantity.sort_values()
# Out:
# 540422   -80995.0
# 61624    -74215.0
# 225529    -9600.0
# 225530    -9600.0
# 4287      -9360.0
#            ...
# 421632     4800.0
# 74614      5568.0
# 502122    12540.0
# 61619     74215.0
# 540421    80995.0
# Name: Quantity, Length: 541909, dtype: float64

# %%
df.UnitPrice.value_counts()
# Out:
# 1.25      50496
# 1.65      38181
# 0.85      28497
# 2.95      27768
# 0.42      24533
#           ...
# 84.21         1
# 46.86         1
# 28.66         1
# 156.45        1
# 224.69        1
# Name: UnitPrice, Length: 1630, dtype: int64

# %%
df.UnitPrice.sort_values()
# Out:
# 299984   -11062.06
# 299983   -11062.06
# 40984         0.00
# 52217         0.00
# 52262         0.00
#             ...
# 16356     13541.33
# 43703     16453.71
# 43702     16888.02
# 524602    17836.46
# 222681    38970.00
# Name: UnitPrice, Length: 541909, dtype: float64

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %% [markdown]
# If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %%
df1[(df1['InvoiceNo'].astype('str').str[0]=='C') & (df1['Quantity'] > 0)]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df1[(df1['InvoiceNo'].astype('str').str[0]=='C') & (df1['Quantity'] < 0)]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount      -1.0
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS      -1.0
# 235      C536391   22556.0    PLASTERS IN TIN CIRCUS PARADE      -12.0
# 236      C536391   21984.0  PACK OF 12 PINK PAISLEY TISSUES      -24.0
# 237      C536391   21983.0  PACK OF 12 BLUE PAISLEY TISSUES      -24.0
# ...          ...       ...                               ...       ...
# 540449   C581490   23144.0   ZINC T-LIGHT HOLDER STARS SMALL     -11.0
# 541541   C581499         M                            Manual      -1.0
# 541715   C581568   21258.0        VICTORIAN SEWING BOX LARGE      -5.0
# 541716   C581569   84978.0  HANGING HEART JAR T-LIGHT HOLDER      -1.0
# 541717   C581569   20979.0     36 PENCILS TUBE RED RETROSPOT      -5.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# ...                    ...        ...         ...             ...
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
#
# [9288 rows x 8 columns]

# %%
df1[df1.CustomerID==14397].tail(15)
#Negative quantities must be subtracted from previous invoice for every customer
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 506163  579128.0   84946.0         ANTIQUE SILVER T-LIGHT GLASS      12.0
# 522268  580394.0   23145.0       ZINC T-LIGHT HOLDER STAR LARGE      36.0
# 522269  580394.0   22178.0      VICTORIAN GLASS HANGING T-LIGHT      48.0
# 522270  580394.0   84946.0         ANTIQUE SILVER T-LIGHT GLASS      24.0
# 522271  580394.0   23144.0      ZINC T-LIGHT HOLDER STARS SMALL      12.0
# 522272  580394.0   22478.0             BIRDHOUSE GARDEN MARKER       20.0
# 522273  580394.0   22596.0  CHRISTMAS STAR WISH LIST CHALKBOARD      12.0
# 533098  581011.0   22178.0      VICTORIAN GLASS HANGING T-LIGHT      48.0
# 533099  581011.0   23144.0      ZINC T-LIGHT HOLDER STARS SMALL      48.0
# 533100  581011.0   23145.0       ZINC T-LIGHT HOLDER STAR LARGE      24.0
# 533101  581011.0   22478.0             BIRDHOUSE GARDEN MARKER       20.0
# 533102  581011.0   20846.0    ZINC HEART LATTICE T-LIGHT HOLDER      24.0
# 533103  581011.0   22600.0        CHRISTMAS RETROSPOT STAR WOOD      12.0
# 540448   C581490   22178.0      VICTORIAN GLASS HANGING T-LIGHT     -12.0
# 540449   C581490   23144.0      ZINC T-LIGHT HOLDER STARS SMALL     -11.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 506163 2011-11-28 12:30:00       1.25     14397.0  United Kingdom
# 522268 2011-12-04 10:53:00       0.95     14397.0  United Kingdom
# 522269 2011-12-04 10:53:00       1.95     14397.0  United Kingdom
# 522270 2011-12-04 10:53:00       1.25     14397.0  United Kingdom
# 522271 2011-12-04 10:53:00       0.83     14397.0  United Kingdom
# 522272 2011-12-04 10:53:00       1.25     14397.0  United Kingdom
# 522273 2011-12-04 10:53:00       1.25     14397.0  United Kingdom
# 533098 2011-12-07 09:22:00       1.95     14397.0  United Kingdom
# 533099 2011-12-07 09:22:00       0.83     14397.0  United Kingdom
# 533100 2011-12-07 09:22:00       0.95     14397.0  United Kingdom
# 533101 2011-12-07 09:22:00       1.25     14397.0  United Kingdom
# 533102 2011-12-07 09:22:00       1.25     14397.0  United Kingdom
# 533103 2011-12-07 09:22:00       0.85     14397.0  United Kingdom
# 540448 2011-12-09 09:57:00       1.95     14397.0  United Kingdom
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom

# %%
cancel_order=df1[df1['InvoiceNo'].astype('str').str[0]=='C']
len(cancel_order['InvoiceNo'].unique())
# Out:
# 3836

# %%
print('Percentage of orders cancelled: {:.2f}% '.format(len(cancel_order['InvoiceNo'].unique())/ df1['InvoiceNo'].nunique() * 100))
# Out:
# Percentage of orders cancelled: 14.81%

# %% [markdown]
# #### 3836 or about 15% of the orders were cancelled. Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
cancel_order.sample(10)
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 75382    C542588   21313.0        GLASS HEART T-LIGHT HOLDER       -5.0
# 383020   C569987   22027.0            TEA PARTY BIRTHDAY CARD    -144.0
# 523338   C580507    72351B     SET/6 PINK  BUTTERFLY T-LIGHTS      -1.0
# 494827   C578276   21535.0       RED RETROSPOT SMALL MILK JUG      -2.0
# 439344   C574447      POST                            POSTAGE      -2.0
# 206119   C554867   21937.0            STRAWBERRY   PICNIC BAG      -1.0
# 97693    C544655   37447.0  CERAMIC CAKE DESIGN SPOTTED PLATE      -5.0
# 86943    C543620   21217.0      RED RETROSPOT ROUND CAKE TINS      -1.0
# 36165    C539438   22655.0        VINTAGE RED KITCHEN CABINET      -1.0
# 531804   C580968   23524.0             WALL ART HORSE & PONY       -6.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 75382  2011-01-28 15:57:00       0.85     12997.0  United Kingdom
# 383020 2011-10-06 19:54:00       0.36     18194.0  United Kingdom
# 523338 2011-12-04 13:37:00       2.10     15867.0  United Kingdom
# 494827 2011-11-23 13:48:00       2.10     17511.0  United Kingdom
# 439344 2011-11-04 11:44:00      40.00     12704.0         Finland
# 206119 2011-05-27 10:48:00       2.95     13050.0  United Kingdom
# 97693  2011-02-22 12:57:00       1.49     13113.0  United Kingdom
# 86943  2011-02-10 14:52:00       9.95     14081.0  United Kingdom
# 36165  2010-12-17 15:11:00     295.00     16607.0  United Kingdom
# 531804 2011-12-06 14:57:00       3.75     15622.0  United Kingdom

# %%
cancel_order.StockCode.value_counts()
# Out:
# M          244
# 22423.0    181
# POST       126
# 22960.0     87
# D           77
#           ...
# 85025C       1
# 22316.0      1
# 22400.0      1
# 21380.0      1
# 23843.0      1
# Name: StockCode, Length: 1947, dtype: int64

# %%
cancel_order[cancel_order['StockCode']=='M']
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 14716    C537610         M      Manual      -1.0 2010-12-07 13:23:00
# 14728    C537613         M      Manual      -1.0 2010-12-07 13:28:00
# 21758    C538124         M      Manual      -4.0 2010-12-09 15:43:00
# 23241    C538189         M      Manual      -1.0 2010-12-10 10:35:00
# 28993    C538681         M      Manual      -1.0 2010-12-13 17:12:00
# ...          ...       ...         ...       ...                 ...
# 520134   C580263         M      Manual     -16.0 2011-12-02 12:43:00
# 523375   C580510         M      Manual      -1.0 2011-12-04 13:48:00
# 533082   C581009         M      Manual      -1.0 2011-12-07 09:15:00
# 534308   C581145         M      Manual      -1.0 2011-12-07 13:48:00
# 541541   C581499         M      Manual      -1.0 2011-12-09 10:28:00
#
#         UnitPrice  CustomerID         Country
# 14716      631.31         NaN  United Kingdom
# 14728      313.78         NaN  United Kingdom
# 21758        0.50     15329.0  United Kingdom
# 23241      133.08         NaN  United Kingdom
# 28993      316.30         NaN  United Kingdom
# ...           ...         ...             ...
# 520134       0.29     12536.0          France
# 523375       1.25     14456.0  United Kingdom
# 533082     125.00     16971.0  United Kingdom
# 534308       9.95     17490.0  United Kingdom
# 541541     224.69     15498.0  United Kingdom
#
# [244 rows x 8 columns]

# %%
cancel_order[cancel_order['StockCode']==22423]
# Out:
#        InvoiceNo StockCode               Description  Quantity  \
# 12402    C537373   22423.0  REGENCY CAKESTAND 3 TIER      -1.0
# 14535    C537602   22423.0  REGENCY CAKESTAND 3 TIER      -2.0
# 18133    C537797   22423.0  REGENCY CAKESTAND 3 TIER      -2.0
# 18247    C537812   22423.0  REGENCY CAKESTAND 3 TIER     -10.0
# 21760    C538124   22423.0  REGENCY CAKESTAND 3 TIER      -1.0
# ...          ...       ...                       ...       ...
# 516185   C579878   22423.0  REGENCY CAKESTAND 3 TIER      -1.0
# 516559   C579933   22423.0  REGENCY CAKESTAND 3 TIER      -1.0
# 523337   C580507   22423.0  REGENCY CAKESTAND 3 TIER      -1.0
# 536911   C581228   22423.0  REGENCY CAKESTAND 3 TIER      -6.0
# 536986   C581235   22423.0  REGENCY CAKESTAND 3 TIER      -1.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 12402  2010-12-06 12:55:00      12.75     14487.0  United Kingdom
# 14535  2010-12-07 12:45:00      10.95     17511.0  United Kingdom
# 18133  2010-12-08 13:07:00      10.95     13113.0  United Kingdom
# 18247  2010-12-08 13:33:00      10.95     14299.0  United Kingdom
# 21760  2010-12-09 15:43:00      12.75     15329.0  United Kingdom
# ...                    ...        ...         ...             ...
# 516185 2011-11-30 17:12:00      12.75     17340.0  United Kingdom
# 516559 2011-12-01 09:44:00      12.75     14853.0  United Kingdom
# 523337 2011-12-04 13:37:00      12.75     15867.0  United Kingdom
# 536911 2011-12-08 10:06:00      10.95     16019.0  United Kingdom
# 536986 2011-12-08 10:34:00      12.75     15950.0  United Kingdom
#
# [181 rows x 8 columns]

# %%
cancel_order[cancel_order['StockCode']=='POST']
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 13052    C537414      POST     POSTAGE      -1.0 2010-12-06 15:09:00
# 32383    C539063      POST     POSTAGE      -1.0 2010-12-15 16:50:00
# 32402    C539073      POST     POSTAGE      -1.0 2010-12-15 17:08:00
# 34591    C539409      POST     POSTAGE      -1.0 2010-12-17 12:58:00
# 39905    C539712      POST     POSTAGE      -1.0 2010-12-21 12:40:00
# ...          ...       ...         ...       ...                 ...
# 507999   C579192      POST     POSTAGE      -4.0 2011-11-28 15:43:00
# 509585   C579366      POST     POSTAGE      -1.0 2011-11-29 11:56:00
# 513076   C579532      POST     POSTAGE      -1.0 2011-11-30 09:21:00
# 519704   C580161      POST     POSTAGE      -2.0 2011-12-02 10:49:00
# 531616   C580957      POST     POSTAGE      -1.0 2011-12-06 14:23:00
#
#         UnitPrice  CustomerID         Country
# 13052        4.41     16861.0  United Kingdom
# 32383       12.34     15107.0  United Kingdom
# 32402        3.50     12971.0  United Kingdom
# 34591       18.00     12720.0         Germany
# 39905        5.75     15602.0  United Kingdom
# ...           ...         ...             ...
# 507999      18.00     12657.0          France
# 509585       9.72     14205.0  United Kingdom
# 513076      18.00     12494.0          France
# 519704      18.00     12700.0          France
# 531616       4.50     12839.0  United Kingdom
#
# [126 rows x 8 columns]

# %%
cancel_order[cancel_order['StockCode']==22960]
# Out:
#        InvoiceNo StockCode               Description  Quantity  \
# 939      C536506   22960.0  JAM MAKING SET WITH JARS      -6.0
# 13055    C537417   22960.0  JAM MAKING SET WITH JARS      -1.0
# 19352    C537853   22960.0  JAM MAKING SET WITH JARS      -2.0
# 29054    C538693   22960.0  JAM MAKING SET WITH JARS      -2.0
# 29523    C538802   22960.0  JAM MAKING SET WITH JARS      -4.0
# ...          ...       ...                       ...       ...
# 464973   C576194   22960.0  JAM MAKING SET WITH JARS      -3.0
# 464997   C576199   22960.0  JAM MAKING SET WITH JARS      -6.0
# 465285   C576216   22960.0  JAM MAKING SET WITH JARS      -3.0
# 526968   C580686   22960.0  JAM MAKING SET WITH JARS      -1.0
# 529975   C580762   22960.0  JAM MAKING SET WITH JARS      -2.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 939    2010-12-01 12:38:00       4.25     17897.0  United Kingdom
# 13055  2010-12-06 15:12:00       4.25     13481.0  United Kingdom
# 19352  2010-12-08 15:57:00       4.25     13370.0  United Kingdom
# 29054  2010-12-14 09:59:00       4.25     16558.0  United Kingdom
# 29523  2010-12-14 11:54:00       4.25     17017.0  United Kingdom
# ...                    ...        ...         ...             ...
# 464973 2011-11-14 12:03:00       4.25     16790.0  United Kingdom
# 464997 2011-11-14 12:13:00       4.25     12610.0           Italy
# 465285 2011-11-14 12:56:00       4.25     12584.0           Italy
# 526968 2011-12-05 15:28:00       4.25     15984.0  United Kingdom
# 529975 2011-12-06 10:32:00       4.25     14543.0  United Kingdom
#
# [87 rows x 8 columns]

# %%
cancel_order[cancel_order['StockCode']=='D']
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 141      C536379         D    Discount      -1.0 2010-12-01 09:41:00
# 9038     C537164         D    Discount      -1.0 2010-12-05 13:21:00
# 14498    C537597         D    Discount      -1.0 2010-12-07 12:34:00
# 19392    C537857         D    Discount      -1.0 2010-12-08 16:00:00
# 31134    C538897         D    Discount      -1.0 2010-12-15 09:14:00
# ...          ...       ...         ...       ...                 ...
# 479868   C577227         D    Discount      -1.0 2011-11-18 12:06:00
# 479869   C577227         D    Discount      -1.0 2011-11-18 12:06:00
# 493613   C578239         D    Discount      -1.0 2011-11-23 12:29:00
# 516221   C579884         D    Discount      -1.0 2011-11-30 17:34:00
# 516455   C579908         D    Discount      -1.0 2011-12-01 08:49:00
#
#         UnitPrice  CustomerID         Country
# 141         27.50     14527.0  United Kingdom
# 9038        29.29     14527.0  United Kingdom
# 14498      281.00     15498.0  United Kingdom
# 19392      267.12     17340.0  United Kingdom
# 31134        5.76     16422.0  United Kingdom
# ...           ...         ...             ...
# 479868      19.82     14527.0  United Kingdom
# 479869      16.76     14527.0  United Kingdom
# 493613      26.33     14912.0           Italy
# 516221      20.53     14527.0  United Kingdom
# 516455      28.68     14527.0  United Kingdom
#
# [77 rows x 8 columns]

# %% [markdown]
# **Now let's find out what a negative UnitPrice means.**

# %%
df1[df1['UnitPrice']<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt       1.0 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt       1.0 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# A bad debt expense is recognized when a receivable is no longer collectible because a customer is unable to fulfill their obligation to pay an outstanding debt due to bankruptcy or other financial problems. Companies that extend credit to their customers report bad debts as an allowance for doubtful accounts on the balance sheet, which is also known as a provision for credit losses.

# %%
df1[df1['Description']=='Adjust bad debt']
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt       1.0 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt       1.0 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt       1.0 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# ### iii. Handling Missing Values

# %%
df1.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
df1.dropna(subset=['CustomerID'], inplace=True)

# %%
df1.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 5225

# %%
df1.drop_duplicates(inplace=True)

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
df1.InvoiceNo.nunique()
# Out:
# 22190

# %%
df1.CustomerID.nunique()
# Out:
# 4372

# %%
pd.DataFrame(df1.groupby('CustomerID')['InvoiceNo'].nunique())['InvoiceNo'].sort_values(ascending=False)
# Out:
# CustomerID
# 14911.0    248
# 12748.0    224
# 17841.0    169
# 14606.0    128
# 13089.0    118
#           ...
# 13877.0      1
# 16400.0      1
# 13878.0      1
# 13886.0      1
# 13670.0      1
# Name: InvoiceNo, Length: 4372, dtype: int64

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
pd.DataFrame(df1.groupby("InvoiceNo")["StockCode"].nunique()).sum()/len(pd.DataFrame(df1.groupby("InvoiceNo")["StockCode"].nunique()))
# Out:
# StockCode    17.876566
# dtype: float64

# %% [markdown]
# There are 17.8 products for per invoice

# %%
pd.DataFrame(df1.groupby("CustomerID")["StockCode"].nunique()).sum()/len(pd.DataFrame(df1.groupby("CustomerID")["StockCode"].nunique()))
# Out:
# StockCode    61.211116
# dtype: float64

# %% [markdown]
# There are 61.2 products for per customer

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
pd.DataFrame(df1.groupby("CustomerID")["StockCode"].nunique())
# Out:
#             StockCode
# CustomerID
# 12346.0             1
# 12347.0           103
# 12348.0            22
# 12349.0            73
# 12350.0            17
# ...               ...
# 18280.0            10
# 18281.0             7
# 18282.0            12
# 18283.0           263
# 18287.0            59
#
# [4372 rows x 1 columns]

# %% [markdown]
# ### vi. Explore Customers by Country

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df1['TotalRevenue']=df1['Quantity']*df1['UnitPrice']

# %%
df1.groupby('Country')['TotalRevenue'].sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          6747156.154
# Netherlands              284661.540
# EIRE                     250001.780
# Germany                  221509.470
# France                   196626.050
# Australia                137009.770
# Switzerland               55739.400
# Spain                     54756.030
# Belgium                   40910.960
# Sweden                    36585.410
# Japan                     35340.620
# Norway                    35163.460
# Portugal                  28995.760
# Finland                   22326.740
# Channel Islands           20076.390
# Denmark                   18768.140
# Italy                     16890.510
# Cyprus                    12858.760
# Austria                   10154.320
# Singapore                  9120.390
# Poland                     7213.140
# Israel                     6988.400
# Greece                     4710.520
# Iceland                    4310.000
# Canada                     3666.380
# Unspecified                2660.770
# Malta                      2505.470
# United Arab Emirates       1902.280
# USA                        1730.920
# Lebanon                    1693.880
# Lithuania                  1661.060
# European Community         1291.750
# Brazil                     1143.600
# RSA                        1002.310
# Czech Republic              707.720
# Bahrain                     548.400
# Saudi Arabia                131.170
# Name: TotalRevenue, dtype: float64

# %% [markdown]
# 2. Visualize number of customer per country

# %%
pd.DataFrame(df1.groupby('Country')['CustomerID'].nunique().sort_values(ascending=False))
# Out:
#                       CustomerID
# Country
# United Kingdom              3950
# Germany                       95
# France                        87
# Spain                         31
# Belgium                       25
# Switzerland                   21
# Portugal                      19
# Italy                         15
# Finland                       12
# Austria                       11
# Norway                        10
# Netherlands                    9
# Australia                      9
# Denmark                        9
# Channel Islands                9
# Cyprus                         8
# Sweden                         8
# Japan                          8
# Poland                         6
# USA                            4
# Canada                         4
# Unspecified                    4
# Israel                         4
# Greece                         4
# EIRE                           3
# Malta                          2
# United Arab Emirates           2
# Bahrain                        2
# Czech Republic                 1
# Lithuania                      1
# Lebanon                        1
# RSA                            1
# Saudi Arabia                   1
# Singapore                      1
# Iceland                        1
# Brazil                         1
# European Community             1

# %%
df3=pd.DataFrame(df1.groupby('Country')['CustomerID'].nunique().sort_values(ascending=False))
fig, ax = plt.subplots(2,1, figsize=(15,15))
sns.barplot(y = df3.index, x= df3['CustomerID'],ax=ax[0])
sns.barplot(y=df3.iloc[1:].index, x= df3['CustomerID'].iloc[1:],ax=ax[1])
# Out:
# <AxesSubplot:xlabel='CustomerID', ylabel='Country'>

# %% [markdown]
# 3. Visualize total cost per country

# %%
df2=pd.DataFrame(df1.groupby('Country')['TotalRevenue'].sum().sort_values(ascending=False))
fig, ax = plt.subplots(2,1, figsize=(15,15))
sns.barplot(y = df2.index, x= df2['TotalRevenue'],ax=ax[0])
sns.barplot(y=df2.iloc[1:].index, x= df2['TotalRevenue'].iloc[1:],ax=ax[1])
# Out:
# <AxesSubplot:xlabel='TotalRevenue', ylabel='Country'>

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df_uk=df1[df1['Country']=='United Kingdom']
df_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1       536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541889  581585.0   22466.0       FAIRY TALE COTTAGE NIGHT LIGHT      12.0
# 541890  581586.0   22061.0  LARGE CAKE STAND  HANGING STRAWBERY       8.0
# 541891  581586.0   23275.0     SET OF 3 HANGING OWLS OLLIE BEAK      24.0
# 541892  581586.0   21217.0        RED RETROSPOT ROUND CAKE TINS      24.0
# 541893  581586.0   20685.0                DOORMAT RED RETROSPOT      10.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541889 2011-12-09 12:31:00       1.95     15804.0  United Kingdom
# 541890 2011-12-09 12:49:00       2.95     13113.0  United Kingdom
# 541891 2011-12-09 12:49:00       1.25     13113.0  United Kingdom
# 541892 2011-12-09 12:49:00       8.95     13113.0  United Kingdom
# 541893 2011-12-09 12:49:00       7.08     13113.0  United Kingdom
#
#         TotalRevenue
# 0              15.30
# 1              20.34
# 2              22.00
# 3              20.34
# 4              20.34
# ...              ...
# 541889         23.40
# 541890         23.60
# 541891         30.00
# 541892        214.80
# 541893         70.80
#
# [356728 rows x 9 columns]

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
df_uk.groupby(['StockCode', 'Description'])['Quantity'].sum().sort_values(ascending=False).head(10)
# Out:
# StockCode  Description
# 84077.0    WORLD WAR 2 GLIDERS ASSTD DESIGNS     47886.0
# 85099B     JUMBO BAG RED RETROSPOT               40777.0
# 84879.0    ASSORTED COLOUR BIRD ORNAMENT         32580.0
# 85123A     WHITE HANGING HEART T-LIGHT HOLDER    32079.0
# 22197.0    POPCORN HOLDER                        28550.0
# 22616.0    PACK OF 12 LONDON TISSUES             24297.0
# 17003.0    BROCADE RING PURSE                    22672.0
# 21212.0    PACK OF 72 RETROSPOT CAKE CASES       22182.0
# 22178.0    VICTORIAN GLASS HANGING T-LIGHT       21427.0
# 21977.0    PACK OF 60 PINK PAISLEY CAKE CASES    19882.0
# Name: Quantity, dtype: float64

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import time
import datetime as dt
from pandas.plotting import scatter_matrix

#Predictive models
import sklearn.cluster as cluster
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_samples, silhouette_score

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1  536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalRevenue
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom         15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom         20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom         22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom         20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom         20.34

# %%
df_uk.describe()
# Out:
#             Quantity      UnitPrice     CustomerID   TotalRevenue
# count  356728.000000  356728.000000  356728.000000  356728.000000
# mean       11.198644       3.268255   15543.795284      18.914008
# std       264.998044      71.162330    1594.286219     455.157029
# min    -80995.000000       0.000000   12346.000000 -168469.600000
# 25%         2.000000       1.250000   14191.000000       3.900000
# 50%         4.000000       1.950000   15513.000000      10.200000
# 75%        12.000000       3.750000   16931.000000      17.700000
# max     80995.000000   38970.000000   18287.000000  168469.600000

# %%
fig, ax = plt.subplots(2,2, figsize=(20,6))
sns.boxplot(df_uk.Quantity, ax=ax[0,0])
sns.kdeplot(df_uk.Quantity,ax=ax[0,1])
sns.boxplot(df_uk.UnitPrice, ax=ax[1,0])
sns.kdeplot(df_uk.UnitPrice,ax=ax[1,1])
ax[0,0].set_xlim([-400,1250])
ax[0,1].set_xlim([-1000,1250]);
ax[1,0].set_xlim([-10,1250])
ax[1,1].set_xlim([0,400]);

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
df_uk2=df_uk[df_uk['Quantity']>=0]

# %%
df_uk2['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:49:00')

# %%
now = dt.date(2011,12,9)

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
df_uk2['Date'] = df_uk2['InvoiceDate'].dt.date

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
df_recency = df_uk2.groupby('CustomerID', as_index=False)['Date'].max()
df_recency.columns = ['CustomerID', 'Last_Purchase_Date']
df_recency.head()
# Out:
#    CustomerID Last_Purchase_Date
# 0     12346.0         2011-01-18
# 1     12747.0         2011-12-07
# 2     12748.0         2011-12-09
# 3     12749.0         2011-12-06
# 4     12820.0         2011-12-06

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
df_recency['Recency'] = df_recency['Last_Purchase_Date'].apply(lambda x: (now - x).days)
df_recency.head()
# Out:
#    CustomerID Last_Purchase_Date  Recency
# 0     12346.0         2011-01-18      325
# 1     12747.0         2011-12-07        2
# 2     12748.0         2011-12-09        0
# 3     12749.0         2011-12-06        3
# 4     12820.0         2011-12-06        3

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
df_recency.drop('Last_Purchase_Date', axis=1, inplace=True)
df_recency.head()
# Out:
#    CustomerID  Recency
# 0     12346.0      325
# 1     12747.0        2
# 2     12748.0        0
# 3     12749.0        3
# 4     12820.0        3

# %% [markdown]
# 6. Plot RFM distributions

# %%
fig, ax = plt.subplots(1,2, figsize=(20,6))
sns.histplot(df_recency.Recency, kde=True, ax=ax[0])
sns.boxplot(df_recency.Recency,ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Recency'>

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
df_uk_copy =  df_uk[df_uk['Quantity']>=0]
df_uk_copy.drop_duplicates(subset=['InvoiceNo', 'CustomerID'], inplace=True)

# %% [markdown]
# 2. Calculate the frequency of purchases

# %%
df_frequency = df_uk_copy.groupby('CustomerID', as_index=False)['InvoiceNo'].count()
df_frequency.columns = ['CustomerID','Frequency']
df_frequency.head()
# Out:
#    CustomerID  Frequency
# 0     12346.0          1
# 1     12747.0         11
# 2     12748.0        210
# 3     12749.0          5
# 4     12820.0          4

# %% [markdown]
# 3. Plot RFM distributions

# %%
fig, ax = plt.subplots(1,2, figsize=(20,6))
sns.histplot(df_frequency.Frequency, kde=True, ax=ax[0])
ax[0].set_xlim([0,50])
ax[0].set_ylim([0,500])
sns.boxplot(df_frequency.Frequency,ax=ax[1])
ax[1].set_xlim([-2,50])
# Out:
# (-2.0, 50.0)

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
df_monetary = df_uk.groupby('CustomerID',as_index=False)['TotalRevenue'].sum()
df_monetary.columns = ['CustomerID', 'Monetary']
df_monetary.head()
# Out:
#    CustomerID  Monetary
# 0     12346.0      0.00
# 1     12747.0   4196.01
# 2     12748.0  28405.56
# 3     12749.0   3868.20
# 4     12820.0    942.34

# %%
df_monetary[df_monetary['Monetary']<0].sort_values('Monetary', ascending=True) #38 Customers
# Out:
#       CustomerID      Monetary
# 3338     17448.0 -4.287630e+03
# 1826     15369.0 -1.592490e+03
# 992      14213.0 -1.192200e+03
# 3451     17603.0 -1.165300e+03
# 2166     15823.0 -8.407600e+02
# 244      13154.0 -6.118600e+02
# 2148     15802.0 -4.514200e+02
# 2480     16252.0 -2.950900e+02
# 3235     17307.0 -1.526400e+02
# 3410     17548.0 -1.414800e+02
# 2094     15728.0 -1.348000e+02
# 3073     17065.0 -1.123500e+02
# 810      13958.0 -1.024500e+02
# 717      13829.0 -1.020000e+02
# 2689     16546.0 -9.593000e+01
# 2024     15638.0 -9.400000e+01
# 611      13672.0 -7.146000e+01
# 3928     18256.0 -5.010000e+01
# 1149     14437.0 -4.340000e+01
# 3839     18141.0 -3.540000e+01
# 624      13693.0 -3.200000e+01
# 2488     16262.0 -3.165000e+01
# 2712     16579.0 -3.060000e+01
# 1988     15590.0 -3.019000e+01
# 2333     16061.0 -2.995000e+01
# 3610     17820.0 -2.405000e+01
# 1290     14627.0 -2.185000e+01
# 927      14119.0 -1.990000e+01
# 1400     14777.0 -1.745000e+01
# 41       12870.0 -1.490000e+01
# 3409     17547.0 -1.180000e+01
# 2625     16454.0 -8.150000e+00
# 2390     16138.0 -7.950000e+00
# 92       12943.0 -3.750000e+00
# 2606     16428.0 -2.950000e+00
# 1328     14679.0 -2.550000e+00
# 3021     16995.0 -1.250000e+00
# 3788     18072.0 -5.329071e-15

# %%
#Monetary is negative because there is no order data that quantity value greater than 0 for these cancelled orders.
df_uk[df_uk['CustomerID']==17448]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 268027   C560372         M      Manual      -1.0 2011-07-18 12:26:00
#
#         UnitPrice  CustomerID         Country  TotalRevenue
# 268027    4287.63     17448.0  United Kingdom      -4287.63

# %%
df_uk[df_uk['CustomerID']==15369]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 268431   C560420         M      Manual      -1.0 2011-07-18 15:11:00
#
#         UnitPrice  CustomerID         Country  TotalRevenue
# 268431    1592.49     15369.0  United Kingdom      -1592.49

# %%
#All negative monetary values set to zero
df_monetary[df_monetary['Monetary']<0]=0
df_monetary[df_monetary['Monetary']<0]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Monetary]
# Index: []

# %% [markdown]
# 2. Plot RFM distributions

# %%
fig, ax = plt.subplots(1,2, figsize=(20,6))
sns.histplot(df_monetary.Monetary, kde=True, ax=ax[0])
sns.boxplot(df_monetary.Monetary,ax=ax[1])
ax[0].set_xlim([0,5000])
ax[0].set_ylim([0,750])
ax[1].set_xlim([-50,5000])
# Out:
# (-50.0, 5000.0)

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
df_merge = df_recency.merge(df_frequency, on='CustomerID')
df_merge.head()
# Out:
#    CustomerID  Recency  Frequency
# 0     12346.0      325          1
# 1     12747.0        2         11
# 2     12748.0        0        210
# 3     12749.0        3          5
# 4     12820.0        3          4

# %%
df_rfm = df_merge.merge(df_monetary,on='CustomerID')
df_rfm.set_index('CustomerID',inplace=True)
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         325          1      0.00
# 12747.0           2         11   4196.01
# 12748.0           0        210  28405.56
# 12749.0           3          5   3868.20
# 12820.0           3          4    942.34

# %%
df_rfm.describe()
# Out:
#            Recency    Frequency       Monetary
# count  3912.000000  3912.000000    3912.000000
# mean     91.419479     4.252812    1727.765811
# std      99.295499     7.212644    6577.213016
# min       0.000000     1.000000       0.000000
# 25%      17.000000     1.000000     289.877500
# 50%      50.000000     2.000000     631.950000
# 75%     141.000000     5.000000    1529.437500
# max     373.000000   210.000000  256438.490000

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %%
quantiles = df_rfm.quantile(q=[0.25,0.5,0.75])
quantiles
# Out:
#       Recency  Frequency   Monetary
# 0.25     17.0        1.0   289.8775
# 0.50     50.0        2.0   631.9500
# 0.75    141.0        5.0  1529.4375

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %%
def Rscore(r):
    if r <= 16:
        return 4
    elif r <= 50:
        return 3
    elif r <= 143: 
        return 2
    else:
        return 1

def Fscore(f):
    if f <= 1:
        return 1
    elif f <= 3:
        return 2
    elif f <= 5: 
        return 3
    else:
        return 4
    
def Mscore(m):
    if m <= 15:
        return 1
    elif m <= 38.5:
        return 2
    elif m <= 106.7: 
        return 3
    else:
        return 4

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %%
rfm_segmentation = df_rfm.copy()
rfm_segmentation['R_Score'] = rfm_segmentation['Recency'].apply(Rscore)
rfm_segmentation['F_Score'] = rfm_segmentation['Frequency'].apply(Fscore)
rfm_segmentation['M_Score'] = rfm_segmentation['Monetary'].apply(Mscore)

# %%
rfm_segmentation.sample(5)
# Out:
#             Recency  Frequency  Monetary  R_Score  F_Score  M_Score
# CustomerID
# 13058.0          24          3    271.40        3        2        4
# 12882.0           9          2   1463.04        4        2        4
# 17088.0          28          4   1991.01        3        3        4
# 13539.0          85          3    605.84        2        2        4
# 16775.0          10         11   1691.51        4        4        4

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.

# %%
rfm_segmentation['RFM_Score'] = rfm_segmentation.R_Score.map(str) \
                            + rfm_segmentation.F_Score.map(str) \
                            + rfm_segmentation.M_Score.map(str)
rfm_segmentation.head()
# Out:
#             Recency  Frequency  Monetary  R_Score  F_Score  M_Score RFM_Score
# CustomerID
# 12346.0         325          1      0.00        1        1        1       111
# 12747.0           2         11   4196.01        4        4        4       444
# 12748.0           0        210  28405.56        4        4        4       444
# 12749.0           3          5   3868.20        4        3        4       434
# 12820.0           3          4    942.34        4        3        4       434

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %%
def rfm_level(digit):
    if sum(int(x) for x in digit)<=4.5:
        return 'Lost Cheap Customers'
    elif sum(int(x) for x in digit)<=6:
        return 'Lost Customers'
    elif sum(int(x) for x in digit)<=7.5:
        return 'Almost Lost'
    elif sum(int(x) for x in digit)<=9:
        return 'Big Spenders'
    elif sum(int(x) for x in digit)<=10.5:
        return 'Loyal Customers'
    else:
        return 'Best Customers'
    
rfm_segmentation['RFM_Level']=rfm_segmentation['RFM_Score'].apply(rfm_level)
    
 #   min=3 ('111'),  mean=7.5,  max=12 ('444')

#    3  4.5 6 7.5 9 10.5  12

# %%
rfm_segmentation.sample(10)
# Out:
#             Recency  Frequency  Monetary  R_Score  F_Score  M_Score RFM_Score  \
# CustomerID
# 14111.0          14          4    688.60        4        3        4       434
# 14708.0           2          3   1096.67        4        2        4       424
# 14157.0          19          2    392.44        3        2        4       324
# 17153.0          24          1    213.78        3        1        4       314
# 14862.0          25          2    841.20        3        2        4       324
# 15990.0          44          2    792.11        3        2        4       324
# 17082.0          33          2   2003.85        3        2        4       324
# 15530.0          21          4   1497.31        3        3        4       334
# 14918.0         115          2   1610.15        2        2        4       224
# 18184.0          15          1     49.80        4        1        3       413
#
#                   RFM_Level
# CustomerID
# 14111.0      Best Customers
# 14708.0     Loyal Customers
# 14157.0        Big Spenders
# 17153.0        Big Spenders
# 14862.0        Big Spenders
# 15990.0        Big Spenders
# 17082.0        Big Spenders
# 15530.0     Loyal Customers
# 14918.0        Big Spenders
# 18184.0        Big Spenders

# %%
#Second Method

df_rfm2=df_rfm.copy()
df_rfm2['R_score'] = pd.cut(x = df_rfm2['Recency'], bins=[-1,
                                                       np.percentile(df_rfm2['Recency'], 25),
                                                       np.percentile(df_rfm2['Recency'], 50),
                                                       np.percentile(df_rfm2['Recency'], 75),
                                                       df_rfm2['Recency'].max()], labels=[4, 3, 2, 1])

df_rfm2['F_score'] = pd.cut(x = df_rfm2['Frequency'], bins=[-1,
                                                       np.percentile(df_rfm2['Frequency'], 25),
                                                       np.percentile(df_rfm2['Frequency'], 50),
                                                       np.percentile(df_rfm2['Frequency'], 75),
                                                       df_rfm2['Frequency'].max()], labels=[1, 2, 3, 4])

df_rfm2['M_score'] = pd.cut(x = df_rfm2['Monetary'], bins=[-1,
                                                       np.percentile(df_rfm2['Monetary'], 25),
                                                       np.percentile(df_rfm2['Monetary'], 50),
                                                       np.percentile(df_rfm2['Monetary'], 75),
                                                       df_rfm2['Monetary'].max()], labels=[1, 2, 3, 4])

df_rfm2['RFM_Score'] = df_rfm2['R_score'].astype(str) + df_rfm2['F_score'].astype(str) + df_rfm2['M_score'].astype(str)

df_rfm2['RFM_Sum'] = df_rfm2['R_score'].astype(float) + df_rfm2['F_score'].astype(float) + df_rfm2['M_score'].astype(float)
df_rfm2
# Out:
#             Recency  Frequency  Monetary R_score F_score M_score RFM_Score  \
# CustomerID
# 12346.0         325          1      0.00       1       1       1       111
# 12747.0           2         11   4196.01       4       4       4       444
# 12748.0           0        210  28405.56       4       4       4       444
# 12749.0           3          5   3868.20       4       3       4       434
# 12820.0           3          4    942.34       4       3       3       433
# ...             ...        ...       ...     ...     ...     ...       ...
# 18280.0         277          1    180.60       1       1       1       111
# 18281.0         180          1     80.82       1       1       1       111
# 18282.0           7          2    176.60       4       2       1       421
# 18283.0           3         16   2045.53       4       4       4       444
# 18287.0          42          3   1837.28       3       3       4       334
#
#             RFM_Sum
# CustomerID
# 12346.0         3.0
# 12747.0        12.0
# 12748.0        12.0
# 12749.0        11.0
# 12820.0        10.0
# ...             ...
# 18280.0         3.0
# 18281.0         3.0
# 18282.0         7.0
# 18283.0        12.0
# 18287.0        10.0
#
# [3912 rows x 8 columns]

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %%
rfm_segmentation[['Recency','Frequency','Monetary','RFM_Level']].groupby('RFM_Level').agg(['min','mean','max'])
# Out:
#                      Recency                  Frequency                  \
#                          min        mean  max       min       mean  max
# RFM_Level
# Almost Lost                0  137.099359  373         1   1.548077    3
# Best Customers             0   12.437500   50         4  11.396991  210
# Big Spenders               1   59.874898  372         1   2.478473   34
# Lost Cheap Customers      63  218.100000  372         1   1.050000    2
# Lost Customers            14  250.510386  373         1   1.005935    2
# Loyal Customers            0   28.907816  143         2   4.156313   17
#
#                      Monetary
#                           min         mean        max
# RFM_Level
# Almost Lost              2.90   526.476397   21535.90
# Best Customers         191.17  5259.034155  256438.49
# Big Spenders            36.56   821.559026    7741.47
# Lost Cheap Customers     0.00    16.347500      38.10
# Lost Customers           0.00   275.680801    3096.00
# Loyal Customers        114.34  1381.198599   12393.70

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %%
plt.figure(figsize=(10,6))
chart1=sns.countplot(data=rfm_segmentation, x='RFM_Level', order=rfm_segmentation.RFM_Level.value_counts().index)
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=rfm_segmentation,  x='RFM_Level', y='Recency')
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(10,6))
ax=sns.boxplot(data=rfm_segmentation,  x='RFM_Level', y='Frequency')
plt.xticks(rotation=45);
ax.set_ylim([0,40])
# Out:
# (0.0, 40.0)

# %%
plt.figure(figsize=(10,6))
ax=sns.boxplot(data=rfm_segmentation,  x='RFM_Level', y='Monetary')
plt.xticks(rotation=45);
ax.set_ylim([0,10000])
# Out:
# (0.0, 10000.0)

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales) we can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %%
rfm_segmentation.RFM_Level.value_counts(ascending=False)
# Out:
# Big Spenders            1231
# Best Customers           864
# Lost Customers           674
# Almost Lost              624
# Loyal Customers          499
# Lost Cheap Customers      20
# Name: RFM_Level, dtype: int64

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into 6 different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
rfm_data = df_rfm
rfm_data.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         325          1      0.00
# 12747.0           2         11   4196.01
# 12748.0           0        210  28405.56
# 12749.0           3          5   3868.20
# 12820.0           3          4    942.34

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
sns.heatmap(rfm_data.corr(),annot=True, cmap="YlGnBu");

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %%
scatter_matrix(rfm_data, alpha =1, figsize = (14,7), diagonal = 'kde');

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. You can use the logarithm method to normalize the values in a column.

# %%
rfm_r_log = np.log(rfm_data['Recency']+0.1) #log(0) is undefined so 0.1 added
rfm_f_log = np.log(rfm_data['Frequency'])
rfm_m_log = np.log(rfm_data['Monetary']+0.1)

# %%
log_data = pd.DataFrame({'Recency': rfm_r_log, 'Frequency': rfm_f_log, 'Monetary': rfm_m_log})
log_data
# Out:
#              Recency  Frequency   Monetary
# CustomerID
# 12346.0     5.784133   0.000000  -2.302585
# 12747.0     0.741937   2.397895   8.341913
# 12748.0    -2.302585   5.347108  10.254344
# 12749.0     1.131402   1.609438   8.260570
# 12820.0     1.131402   1.386294   6.848472
# ...              ...        ...        ...
# 18280.0     5.624378   0.000000   5.196838
# 18281.0     5.193512   0.000000   4.393461
# 18282.0     1.960095   0.693147   5.174453
# 18283.0     1.131402   2.772589   7.623461
# 18287.0     3.740048   1.098612   7.516096
#
# [3912 rows x 3 columns]

# %%
log_data.describe()
# Out:
#            Recency    Frequency     Monetary
# count  3912.000000  3912.000000  3912.000000
# mean      3.721269     0.946959     6.496063
# std       1.517091     0.900676     1.310226
# min      -2.302585     0.000000    -2.302585
# 25%       2.839078     0.000000     5.669803
# 50%       3.914021     0.693147     6.448969
# 75%       4.949469     1.609438     7.332721
# max       5.921846     5.347108    12.454644

# %% [markdown]
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %%
scatter_matrix(log_data, alpha = 1, figsize = (14,7), diagonal = 'kde');

# %%
sns.heatmap(log_data.corr(),annot=True, cmap="YlGnBu");

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %%
ssd = [] #sum squared distance

K = range(2,10)

for k in K:
    model = KMeans(n_clusters=k)
    model.fit(log_data)
    ssd.append(model.inertia_)

# %%
plt.plot(K, ssd, 'bo-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k');

# %%
#conda install -c districtdatalabs yellowbrick

# %%
from yellowbrick.cluster import KElbowVisualizer

model_ = KMeans(random_state=42)
visualizer = KElbowVisualizer(model_, k=(2,9))

visualizer.fit(log_data)        # Fit the data to the visualizer
visualizer.show();

# %% [markdown]
# The best elbow score obtained is when there are 4 clusters.

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
range_n_clusters = range(2,9)
for num_clusters in range_n_clusters:
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(log_data)
    cluster_labels = kmeans.labels_
    # silhouette score
    silhouette_avg = silhouette_score(log_data, cluster_labels)
    print(f"For n_clusters={num_clusters}, the silhouette score is {silhouette_avg}")
# Out:
# For n_clusters=2, the silhouette score is 0.41631419876865083
# For n_clusters=3, the silhouette score is 0.3322096111084122
# For n_clusters=4, the silhouette score is 0.34124887336305626
# For n_clusters=5, the silhouette score is 0.31036434646764294
# For n_clusters=6, the silhouette score is 0.31835697607002295
# For n_clusters=7, the silhouette score is 0.3254848776108608
# For n_clusters=8, the silhouette score is 0.3226252502310438

# %% [markdown]
# The best silhouette score obtained is when there are 2 clusters.

# %%
from yellowbrick.cluster import SilhouetteVisualizer

model3 = KMeans(n_clusters=2, random_state=42)
visualizer = SilhouetteVisualizer(model3)

visualizer.fit(log_data)    # Fit the data to the visualizer
visualizer.poof();

# %%
from yellowbrick.cluster import SilhouetteVisualizer

model3 = KMeans(n_clusters=4, random_state=42)
visualizer = SilhouetteVisualizer(model3)

visualizer.fit(log_data)    # Fit the data to the visualizer
visualizer.poof();

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %%
model = KMeans(n_clusters =4, random_state=42)
model.fit_predict(log_data)
# Out:
# array([0, 1, 1, ..., 3, 1, 2])

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %%
clusters = model.labels_

# %%
log_data["ClusterID"] = clusters
log_data
# Out:
#              Recency  Frequency   Monetary  ClusterID
# CustomerID
# 12346.0     5.784133   0.000000  -2.302585          0
# 12747.0     0.741937   2.397895   8.341913          1
# 12748.0    -2.302585   5.347108  10.254344          1
# 12749.0     1.131402   1.609438   8.260570          1
# 12820.0     1.131402   1.386294   6.848472          1
# ...              ...        ...        ...        ...
# 18280.0     5.624378   0.000000   5.196838          0
# 18281.0     5.193512   0.000000   4.393461          0
# 18282.0     1.960095   0.693147   5.174453          3
# 18283.0     1.131402   2.772589   7.623461          1
# 18287.0     3.740048   1.098612   7.516096          2
#
# [3912 rows x 4 columns]

# %%
centers = model.cluster_centers_

# %%
sns.scatterplot(log_data["Recency"], log_data["Frequency"], hue = log_data.ClusterID, legend='full', palette="deep", alpha=0.7)
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
sns.scatterplot(log_data["Frequency"], log_data["Monetary"], hue = log_data.ClusterID, legend='full', palette="deep", alpha=0.7)
plt.scatter(centers[:, 1], centers[:, 2], c='black', s=200, alpha=0.5);

# %%
sns.scatterplot(log_data["Monetary"], log_data["Recency"], hue = log_data.ClusterID, legend='full', palette="deep", alpha=0.7)
plt.scatter(centers[:, 2], centers[:, 0], c='black', s=200, alpha=0.5);

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, figsize=(10, 12))
sns.boxplot(log_data["ClusterID"], log_data["Recency"], ax=ax1)
sns.boxplot(log_data["ClusterID"], log_data["Frequency"], ax=ax2)
sns.boxplot(log_data["ClusterID"], log_data["Monetary"], ax=ax3);

# %%
import pickle
filename = 'customer_segmentation_model'
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# ### iv. Assign the Label

# %% [markdown]
# Values were collected for comparison in the table created by using the Recency, Monetary and Frequency averages of 4 clusters. Recency value was subtracted from the others because it is better to have a lower Recency value.

# %%
a=log_data.groupby('ClusterID').mean()
a['Score']=a['Frequency']+a['Monetary']-a['Recency']
a
# Out:
#             Recency  Frequency  Monetary     Score
# ClusterID
# 0          5.126233   0.231053  5.499093  0.603913
# 1          1.405620   2.232884  8.118373  8.945636
# 2          3.880943   1.399775  7.267936  4.786768
# 3          2.891957   0.507514  5.811598  3.427155

# %% [markdown]
# Cluster 0: These customers are named 'Lost Customers' because their Frequency and Monetary values are the lowest and Recency value is the highest.
#
# Cluster 1: These customers are named 'Best Customers' because their Frequency and Monetary values are the highest and Recency value is the lowest.
#
# Cluster 2: Since they are the second group to spend the most money, although they have not shopped recently compared to Cluster 3, this group is labeled as 'Big Spenders'.
#
# Cluster 3: This group is called 'Loyal Customers' because they are the second group to shop recently, even though they don't spend a lot of money compared to Cluster 2.

# %%
def assign_label(x):
    if x==0:
        return 'Lost Customers'
    elif x==1:
        return 'Best Customer'
    elif x==2:
        return 'Big Spenders'
    else:
        return 'Loyal Customers'
    
log_data['Label']=log_data['ClusterID'].apply(assign_label)
log_data.drop('ClusterID', axis=1, inplace=True)
log_data
# Out:
#              Recency  Frequency   Monetary            Label
# CustomerID
# 12346.0     5.784133   0.000000  -2.302585   Lost Customers
# 12747.0     0.741937   2.397895   8.341913    Best Customer
# 12748.0    -2.302585   5.347108  10.254344    Best Customer
# 12749.0     1.131402   1.609438   8.260570    Best Customer
# 12820.0     1.131402   1.386294   6.848472    Best Customer
# ...              ...        ...        ...              ...
# 18280.0     5.624378   0.000000   5.196838   Lost Customers
# 18281.0     5.193512   0.000000   4.393461   Lost Customers
# 18282.0     1.960095   0.693147   5.174453  Loyal Customers
# 18283.0     1.131402   2.772589   7.623461    Best Customer
# 18287.0     3.740048   1.098612   7.516096     Big Spenders
#
# [3912 rows x 4 columns]

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the Customer Segmentation with the labels found by K-Means.

# %%
RFM_Level=['Best Customers','Loyal Customers', 'Big Spenders', 'Almost Lost', 'Lost Customers', 'Lost Cheap Customers']
Label=['Best Customer','Big Spenders', 'Loyal Customers', 'Lost Customers']
pd.crosstab(log_data['Label'],rfm_segmentation['RFM_Level'])[RFM_Level].loc[Label]
# Out:
# RFM_Level        Best Customers  Loyal Customers  Big Spenders  Almost Lost  \
# Label
# Best Customer               579               42             1            0
# Big Spenders                243              277           557           65
# Loyal Customers              42              180           523           37
# Lost Customers                0                0           150          522
#
# RFM_Level        Lost Customers  Lost Cheap Customers
# Label
# Best Customer                 0                     0
# Big Spenders                  3                     0
# Loyal Customers               4                     0
# Lost Customers              667                    20

# %%
log_data.groupby('Label').agg(['min','mean','max'])
# Out:
#                   Recency                     Frequency                      \
#                       min      mean       max       min      mean       max
# Label
# Best Customer   -2.302585  1.405620  3.640214       0.0  2.232884  5.347108
# Big Spenders     2.312535  3.880943  5.919163       0.0  1.399775  3.526361
# Lost Customers   3.404525  5.126233  5.921846       0.0  0.231053  1.791759
# Loyal Customers -2.302585  2.891957  4.112512       0.0  0.507514  1.945910
#
#                  Monetary
#                       min      mean        max
# Label
# Best Customer    5.988460  8.118373  12.454644
# Big Spenders     5.933888  7.267936   9.977481
# Lost Customers  -2.302585  5.499093   7.602152
# Loyal Customers -2.302585  5.811598   7.288340

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# **Conclusion Example :**
#
# - Cluster 0 : The first cluster belongs to the "Best Customers" segment which we saw earlier as they purchase recently (R=4), frequent buyers (F=4), and spent the most (M=4)
#
# - Cluster 1 : Second cluster can be interpreted as passer customers as their last purchase is long ago (R<=1),purchased very few (F>=2 & F < 4) and spent little (M>=4 & M < 4).Company has to come up with new strategies to make them permanent members. Low value customers
# - Cluster 2 : The third cluster is more related to the "Almost Lost" segment as they Haven’t purchased for some time(R=1), but used to purchase frequently and spent a lot.

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %%
df4=df1[['CustomerID','Quantity', 'UnitPrice','TotalRevenue', 'InvoiceNo','InvoiceDate']]
df4.head()
# Out:
#    CustomerID  Quantity  UnitPrice  TotalRevenue InvoiceNo         InvoiceDate
# 0     17850.0       6.0       2.55         15.30  536365.0 2010-12-01 08:26:00
# 1     17850.0       6.0       3.39         20.34  536365.0 2010-12-01 08:26:00
# 2     17850.0       8.0       2.75         22.00  536365.0 2010-12-01 08:26:00
# 3     17850.0       6.0       3.39         20.34  536365.0 2010-12-01 08:26:00
# 4     17850.0       6.0       3.39         20.34  536365.0 2010-12-01 08:26:00

# %%
# Extract year and month from the the column. strftim convert datetime to string 

def extract_ym(df):
    return df.apply(lambda x: x.strftime('%Y-%m')).astype('datetime64[ns]')

# %% [markdown]
# Now we will use the function created above to convert all the invoice dates into respective month date format.

# %%
df4['InvoiceDate']=extract_ym(df4.InvoiceDate)
df4['CohortDate'] = df4.groupby('CustomerID')['InvoiceDate'].transform('min')
df4
# Out:
#         CustomerID  Quantity  UnitPrice  TotalRevenue InvoiceNo InvoiceDate  \
# 0          17850.0       6.0       2.55         15.30  536365.0  2010-12-01
# 1          17850.0       6.0       3.39         20.34  536365.0  2010-12-01
# 2          17850.0       8.0       2.75         22.00  536365.0  2010-12-01
# 3          17850.0       6.0       3.39         20.34  536365.0  2010-12-01
# 4          17850.0       6.0       3.39         20.34  536365.0  2010-12-01
# ...            ...       ...        ...           ...       ...         ...
# 541904     12680.0      12.0       0.85         10.20  581587.0  2011-12-01
# 541905     12680.0       6.0       2.10         12.60  581587.0  2011-12-01
# 541906     12680.0       4.0       4.15         16.60  581587.0  2011-12-01
# 541907     12680.0       4.0       4.15         16.60  581587.0  2011-12-01
# 541908     12680.0       3.0       4.95         14.85  581587.0  2011-12-01
#
#        CohortDate
# 0      2010-12-01
# 1      2010-12-01
# 2      2010-12-01
# 3      2010-12-01
# 4      2010-12-01
# ...           ...
# 541904 2011-08-01
# 541905 2011-08-01
# 541906 2011-08-01
# 541907 2011-08-01
# 541908 2011-08-01
#
# [401604 rows x 7 columns]

# %% [markdown]
# Second Method (Without creating function):

# %%
f=lambda x:pd.to_datetime(x).dt.to_period('M')

#f(df4['InvoiceDate'])

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.

# %%
def get_date_int(df, column, column1):
    InvoiceYears = df[column].dt.year
    InvoiceMonths = df[column].dt.month
    CohortYears = df[column1].dt.year
    CohortMonths =df[column1].dt.month
    return InvoiceYears, InvoiceMonths, CohortYears, CohortMonths

# %% [markdown]
# Second Method (Without creating function):

# %%
# df4['InvoiceMonth']=extract_ym(df.InvoiceDate)

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 seperate series for each of the two columns

# %%
df4['InvoiceYears']=get_date_int(df4, 'InvoiceDate', 'CohortDate')[0]
df4['InvoiceMonths']=get_date_int(df4, 'InvoiceDate', 'CohortDate')[1]
df4['CohortYears']=get_date_int(df4, 'InvoiceDate', 'CohortDate')[2]
df4['CohortMonths']=get_date_int(df4, 'InvoiceDate', 'CohortDate')[3]
df4
# Out:
#         CustomerID  Quantity  UnitPrice  TotalRevenue InvoiceNo InvoiceDate  \
# 0          17850.0       6.0       2.55         15.30  536365.0  2010-12-01
# 1          17850.0       6.0       3.39         20.34  536365.0  2010-12-01
# 2          17850.0       8.0       2.75         22.00  536365.0  2010-12-01
# 3          17850.0       6.0       3.39         20.34  536365.0  2010-12-01
# 4          17850.0       6.0       3.39         20.34  536365.0  2010-12-01
# ...            ...       ...        ...           ...       ...         ...
# 541904     12680.0      12.0       0.85         10.20  581587.0  2011-12-01
# 541905     12680.0       6.0       2.10         12.60  581587.0  2011-12-01
# 541906     12680.0       4.0       4.15         16.60  581587.0  2011-12-01
# 541907     12680.0       4.0       4.15         16.60  581587.0  2011-12-01
# 541908     12680.0       3.0       4.95         14.85  581587.0  2011-12-01
#
#        CohortDate  InvoiceYears  InvoiceMonths  CohortYears  CohortMonths
# 0      2010-12-01          2010             12         2010            12
# 1      2010-12-01          2010             12         2010            12
# 2      2010-12-01          2010             12         2010            12
# 3      2010-12-01          2010             12         2010            12
# 4      2010-12-01          2010             12         2010            12
# ...           ...           ...            ...          ...           ...
# 541904 2011-08-01          2011             12         2011             8
# 541905 2011-08-01          2011             12         2011             8
# 541906 2011-08-01          2011             12         2011             8
# 541907 2011-08-01          2011             12         2011             8
# 541908 2011-08-01          2011             12         2011             8
#
# [401604 rows x 11 columns]

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %%
years_diff = df4['InvoiceYears'] - df4['CohortYears']
months_diff = df4['InvoiceMonths'] - df4['CohortMonths']

# %%
df4['CohortIndex'] = years_diff * 360 + months_diff *30 
df4.sample(20)
# Day value of the year accepted as 360, because otherwise cohortindex will not be multiple of 30 for different year datas.
# Out:
#         CustomerID  Quantity  UnitPrice  TotalRevenue InvoiceNo InvoiceDate  \
# 475103     14825.0      10.0       2.08         20.80  576862.0  2011-11-01
# 369243     15321.0       8.0       4.15         33.20  569021.0  2011-09-01
# 351411     12520.0       6.0       2.55         15.30  567666.0  2011-09-01
# 364592     14606.0       2.0       2.10          4.20  568667.0  2011-09-01
# 336851     16984.0       2.0       1.45          2.90  566408.0  2011-09-01
# 452314     13209.0       2.0       7.65         15.30  575331.0  2011-11-01
# 493200     14336.0      12.0       0.83          9.96  578187.0  2011-11-01
# 7903       12567.0      12.0       1.25         15.00  537065.0  2010-12-01
# 149828     15189.0       3.0       4.95         14.85  549305.0  2011-04-01
# 231826     16813.0       2.0       1.95          3.90  557283.0  2011-06-01
# 352824     17997.0      10.0       0.79          7.90  567692.0  2011-09-01
# 325567     13548.0       1.0       9.95          9.95  565445.0  2011-09-01
# 540253     12748.0       1.0       1.25          1.25  581474.0  2011-12-01
# 337967     12940.0       4.0       3.25         13.00  566488.0  2011-09-01
# 527313     17404.0      40.0       5.95        238.00  580704.0  2011-12-01
# 266701     17863.0      24.0       0.42         10.08  560265.0  2011-07-01
# 521304     17238.0       2.0       2.10          4.20  580358.0  2011-12-01
# 294178     13869.0      12.0       0.65          7.80  562688.0  2011-08-01
# 258857     15856.0       3.0       0.42          1.26  559674.0  2011-07-01
# 130148     13475.0      12.0       1.25         15.00  547413.0  2011-03-01
#
#        CohortDate  InvoiceYears  InvoiceMonths  CohortYears  CohortMonths  \
# 475103 2010-12-01          2011             11         2010            12
# 369243 2011-02-01          2011              9         2011             2
# 351411 2011-03-01          2011              9         2011             3
# 364592 2010-12-01          2011              9         2010            12
# 336851 2011-08-01          2011              9         2011             8
# 452314 2010-12-01          2011             11         2010            12
# 493200 2011-03-01          2011             11         2011             3
# 7903   2010-12-01          2010             12         2010            12
# 149828 2011-01-01          2011              4         2011             1
# 231826 2011-05-01          2011              6         2011             5
# 352824 2011-06-01          2011              9         2011             6
# 325567 2011-04-01          2011              9         2011             4
# 540253 2010-12-01          2011             12         2010            12
# 337967 2011-09-01          2011              9         2011             9
# 527313 2010-12-01          2011             12         2010            12
# 266701 2010-12-01          2011              7         2010            12
# 521304 2010-12-01          2011             12         2010            12
# 294178 2010-12-01          2011              8         2010            12
# 258857 2010-12-01          2011              7         2010            12
# 130148 2011-02-01          2011              3         2011             2
#
#         CohortIndex
# 475103          330
# 369243          210
# 351411          180
# 364592          270
# 336851           30
# 452314          330
# 493200          240
# 7903              0
# 149828           90
# 231826           30
# 352824           90
# 325567          150
# 540253          360
# 337967            0
# 527313          360
# 266701          210
# 521304          360
# 294178          240
# 258857          210
# 130148           30

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
df4[df4['CustomerID']==17677].head(30) #cohort index explanation
# Out:
#        CustomerID  Quantity  UnitPrice  TotalRevenue InvoiceNo InvoiceDate  \
# 10153     17677.0       2.0       8.50         17.00  537227.0  2010-12-01
# 10154     17677.0       6.0       1.95         11.70  537227.0  2010-12-01
# 10155     17677.0       2.0       8.50         17.00  537227.0  2010-12-01
# 10156     17677.0     120.0       0.42         50.40  537227.0  2010-12-01
# 10157     17677.0      48.0       0.55         26.40  537227.0  2010-12-01
# 10158     17677.0      48.0       0.55         26.40  537227.0  2010-12-01
# 10159     17677.0      48.0       0.55         26.40  537227.0  2010-12-01
# 10160     17677.0      12.0       0.85         10.20  537227.0  2010-12-01
# 10161     17677.0      48.0       2.10        100.80  537227.0  2010-12-01
# 10162     17677.0      12.0       1.25         15.00  537227.0  2010-12-01
# 10163     17677.0      12.0       1.25         15.00  537227.0  2010-12-01
# 10164     17677.0       3.0       5.95         17.85  537227.0  2010-12-01
# 10165     17677.0       4.0       4.65         18.60  537227.0  2010-12-01
# 10166     17677.0      48.0       2.10        100.80  537227.0  2010-12-01
# 10167     17677.0      48.0       2.10        100.80  537227.0  2010-12-01
# 10168     17677.0      24.0       0.85         20.40  537227.0  2010-12-01
# 10169     17677.0      12.0       1.65         19.80  537227.0  2010-12-01
# 10170     17677.0     100.0       1.45        145.00  537227.0  2010-12-01
# 10171     17677.0     100.0       1.65        165.00  537227.0  2010-12-01
# 10172     17677.0       3.0       5.95         17.85  537227.0  2010-12-01
# 10173     17677.0      12.0       2.10         25.20  537228.0  2010-12-01
# 10174     17677.0      12.0       1.45         17.40  537229.0  2010-12-01
# 17537     17677.0      72.0       2.10        151.20  537766.0  2010-12-01
# 17538     17677.0      72.0       2.75        198.00  537766.0  2010-12-01
# 17539     17677.0      72.0       2.10        151.20  537766.0  2010-12-01
# 17540     17677.0      72.0       2.10        151.20  537766.0  2010-12-01
# 29204     17677.0      -1.0       8.50         -8.50   C538712  2010-12-01
# 66833     17677.0      -1.0       2.10         -2.10   C541823  2011-01-01
# 70661     17677.0      12.0       0.85         10.20  542093.0  2011-01-01
# 70662     17677.0      12.0       1.65         19.80  542093.0  2011-01-01
#
#       CohortDate  InvoiceYears  InvoiceMonths  CohortYears  CohortMonths  \
# 10153 2010-12-01          2010             12         2010            12
# 10154 2010-12-01          2010             12         2010            12
# 10155 2010-12-01          2010             12         2010            12
# 10156 2010-12-01          2010             12         2010            12
# 10157 2010-12-01          2010             12         2010            12
# 10158 2010-12-01          2010             12         2010            12
# 10159 2010-12-01          2010             12         2010            12
# 10160 2010-12-01          2010             12         2010            12
# 10161 2010-12-01          2010             12         2010            12
# 10162 2010-12-01          2010             12         2010            12
# 10163 2010-12-01          2010             12         2010            12
# 10164 2010-12-01          2010             12         2010            12
# 10165 2010-12-01          2010             12         2010            12
# 10166 2010-12-01          2010             12         2010            12
# 10167 2010-12-01          2010             12         2010            12
# 10168 2010-12-01          2010             12         2010            12
# 10169 2010-12-01          2010             12         2010            12
# 10170 2010-12-01          2010             12         2010            12
# 10171 2010-12-01          2010             12         2010            12
# 10172 2010-12-01          2010             12         2010            12
# 10173 2010-12-01          2010             12         2010            12
# 10174 2010-12-01          2010             12         2010            12
# 17537 2010-12-01          2010             12         2010            12
# 17538 2010-12-01          2010             12         2010            12
# 17539 2010-12-01          2010             12         2010            12
# 17540 2010-12-01          2010             12         2010            12
# 29204 2010-12-01          2010             12         2010            12
# 66833 2010-12-01          2011              1         2010            12
# 70661 2010-12-01          2011              1         2010            12
# 70662 2010-12-01          2011              1         2010            12
#
#        CohortIndex
# 10153            0
# 10154            0
# 10155            0
# 10156            0
# 10157            0
# 10158            0
# 10159            0
# 10160            0
# 10161            0
# 10162            0
# 10163            0
# 10164            0
# 10165            0
# 10166            0
# 10167            0
# 10168            0
# 10169            0
# 10170            0
# 10171            0
# 10172            0
# 10173            0
# 10174            0
# 17537            0
# 17538            0
# 17539            0
# 17540            0
# 29204            0
# 66833           30
# 70661           30
# 70662           30

# %% [markdown]
# As you go from left to right on the pivot table, it shows the number of old customers who continue shopping. As you scroll from top to bottom on the pivot table, it shows first-time shoppers.

# %%
cohort_data = df4.groupby(['CohortDate', 'CohortIndex'])['CustomerID'].apply(pd.Series.nunique)
cohort_data = cohort_data.reset_index()
cohort_counts = cohort_data.pivot(index='CohortDate',
                                  columns='CohortIndex',
                                  values='CustomerID')
cohort_counts.index = cohort_counts.index.strftime('%m-%Y')
cohort_counts
# Out:
# CohortIndex    0      30     60     90     120    150    180    210    240  \
# CohortDate
# 12-2010      948.0  362.0  317.0  367.0  341.0  376.0  360.0  336.0  336.0
# 01-2011      421.0  101.0  119.0  102.0  138.0  126.0  110.0  108.0  131.0
# 02-2011      380.0   94.0   73.0  106.0  102.0   94.0   97.0  107.0   98.0
# 03-2011      440.0   84.0  112.0   96.0  102.0   78.0  116.0  105.0  127.0
# 04-2011      299.0   68.0   66.0   63.0   62.0   71.0   69.0   78.0   25.0
# 05-2011      279.0   66.0   48.0   48.0   60.0   68.0   74.0   29.0    NaN
# 06-2011      235.0   49.0   44.0   64.0   58.0   79.0   24.0    NaN    NaN
# 07-2011      191.0   40.0   39.0   44.0   52.0   22.0    NaN    NaN    NaN
# 08-2011      167.0   42.0   42.0   42.0   23.0    NaN    NaN    NaN    NaN
# 09-2011      298.0   89.0   97.0   36.0    NaN    NaN    NaN    NaN    NaN
# 10-2011      352.0   93.0   46.0    NaN    NaN    NaN    NaN    NaN    NaN
# 11-2011      321.0   43.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12-2011       41.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# CohortIndex    270    300    330    360
# CohortDate
# 12-2010      374.0  354.0  474.0  260.0
# 01-2011      146.0  155.0   63.0    NaN
# 02-2011      119.0   35.0    NaN    NaN
# 03-2011       39.0    NaN    NaN    NaN
# 04-2011        NaN    NaN    NaN    NaN
# 05-2011        NaN    NaN    NaN    NaN
# 06-2011        NaN    NaN    NaN    NaN
# 07-2011        NaN    NaN    NaN    NaN
# 08-2011        NaN    NaN    NaN    NaN
# 09-2011        NaN    NaN    NaN    NaN
# 10-2011        NaN    NaN    NaN    NaN
# 11-2011        NaN    NaN    NaN    NaN
# 12-2011        NaN    NaN    NaN    NaN

# %%
#cohort_data[cohort_data['CohortDate']=='2010-12-01']
df4[(df4.groupby('CustomerID')['InvoiceDate'].transform('min')=='2010-12-01') & (df4['CohortIndex']==0)].nunique()
# Out:
# CustomerID        948
# Quantity          144
# UnitPrice         147
# TotalRevenue     1078
# InvoiceNo        1708
# InvoiceDate         1
# CohortDate          1
# InvoiceYears        1
# InvoiceMonths       1
# CohortYears         1
# CohortMonths        1
# CohortIndex         1
# dtype: int64

# %%
cohort_sizes = cohort_counts.iloc[:,0]
retention = cohort_counts.divide(cohort_sizes, axis=0).apply(lambda x: round(x,2))
retention.round(3) * 100
# Out:
# CohortIndex    0     30    60    90    120   150   180   210   240   270  \
# CohortDate
# 12-2010      100.0  38.0  33.0  39.0  36.0  40.0  38.0  35.0  35.0  39.0
# 01-2011      100.0  24.0  28.0  24.0  33.0  30.0  26.0  26.0  31.0  35.0
# 02-2011      100.0  25.0  19.0  28.0  27.0  25.0  26.0  28.0  26.0  31.0
# 03-2011      100.0  19.0  25.0  22.0  23.0  18.0  26.0  24.0  29.0   9.0
# 04-2011      100.0  23.0  22.0  21.0  21.0  24.0  23.0  26.0   8.0   NaN
# 05-2011      100.0  24.0  17.0  17.0  22.0  24.0  27.0  10.0   NaN   NaN
# 06-2011      100.0  21.0  19.0  27.0  25.0  34.0  10.0   NaN   NaN   NaN
# 07-2011      100.0  21.0  20.0  23.0  27.0  12.0   NaN   NaN   NaN   NaN
# 08-2011      100.0  25.0  25.0  25.0  14.0   NaN   NaN   NaN   NaN   NaN
# 09-2011      100.0  30.0  33.0  12.0   NaN   NaN   NaN   NaN   NaN   NaN
# 10-2011      100.0  26.0  13.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 11-2011      100.0  13.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12-2011      100.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# CohortIndex   300   330   360
# CohortDate
# 12-2010      37.0  50.0  27.0
# 01-2011      37.0  15.0   NaN
# 02-2011       9.0   NaN   NaN
# 03-2011       NaN   NaN   NaN
# 04-2011       NaN   NaN   NaN
# 05-2011       NaN   NaN   NaN
# 06-2011       NaN   NaN   NaN
# 07-2011       NaN   NaN   NaN
# 08-2011       NaN   NaN   NaN
# 09-2011       NaN   NaN   NaN
# 10-2011       NaN   NaN   NaN
# 11-2011       NaN   NaN   NaN
# 12-2011       NaN   NaN   NaN

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %%
retention.T.columns
plt.figure(figsize=(15, 6))
plt.title('Retention Rates')
sns.heatmap(data = retention, annot = True, fmt = '.0%',vmin = 0.0,vmax = 0.5, cmap = 'BuGn')
plt.show()

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
grouping_qty = df4.groupby(['CohortDate', 'CohortIndex'])
cohort_data_qty = grouping_qty['Quantity'].mean()
cohort_data_qty = cohort_data_qty.reset_index()
average_quantity = cohort_data_qty.pivot(index='CohortDate',
                                     columns='CohortIndex',
                                     values='Quantity')
average_quantity.index = average_quantity.index.strftime('%m-%Y')
average_quantity
# Out:
# CohortIndex        0          30         60         90         120        150  \
# CohortDate
# 12-2010      11.200463  14.691852  15.108447  14.954097  13.054649  14.416287
# 01-2011      10.127231  12.704190  12.429557  11.032382  12.288608  15.006101
# 02-2011      10.924450  12.251366  18.563808  12.018144  11.167271  11.476727
# 03-2011       9.818050   9.972109  12.249296   9.483094  13.037510  12.369617
# 04-2011       9.803935  10.130252   9.432453  11.622102  11.645560   8.315994
# 05-2011      10.977360   9.138087  14.023864  11.805435  10.973613   8.740725
# 06-2011      10.411028  13.859783  10.509642  13.384102  10.360800   9.901184
# 07-2011       9.804225  12.700952   7.229385   7.929151   6.101961   7.111538
# 08-2011       9.941459   5.983114   5.371409   5.972992   6.980110        NaN
# 09-2011      12.003023   5.551129   7.657590   8.873418        NaN        NaN
# 10-2011       8.553545   7.056196   8.079686        NaN        NaN        NaN
# 11-2011       8.901297   9.508021        NaN        NaN        NaN        NaN
# 12-2011      14.795478        NaN        NaN        NaN        NaN        NaN
#
# CohortIndex        180        210        240        270        300        330  \
# CohortDate
# 12-2010      15.306910  14.879447  16.764934  16.809158  17.528956  13.019471
# 01-2011      14.302480  14.519414  11.451025   9.982762   9.256968   9.737305
# 02-2011      13.378526  12.448602  10.381961  12.043074  12.702765        NaN
# 03-2011      13.221102  12.263293  10.662973   9.091004        NaN        NaN
# 04-2011       9.777895   9.480778   7.403071        NaN        NaN        NaN
# 05-2011      10.275862   7.576774        NaN        NaN        NaN        NaN
# 06-2011       9.348609        NaN        NaN        NaN        NaN        NaN
# 07-2011            NaN        NaN        NaN        NaN        NaN        NaN
# 08-2011            NaN        NaN        NaN        NaN        NaN        NaN
# 09-2011            NaN        NaN        NaN        NaN        NaN        NaN
# 10-2011            NaN        NaN        NaN        NaN        NaN        NaN
# 11-2011            NaN        NaN        NaN        NaN        NaN        NaN
# 12-2011            NaN        NaN        NaN        NaN        NaN        NaN
#
# CohortIndex        360
# CohortDate
# 12-2010      14.901201
# 01-2011            NaN
# 02-2011            NaN
# 03-2011            NaN
# 04-2011            NaN
# 05-2011            NaN
# 06-2011            NaN
# 07-2011            NaN
# 08-2011            NaN
# 09-2011            NaN
# 10-2011            NaN
# 11-2011            NaN
# 12-2011            NaN

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(15, 6))
plt.title('Average Quantity')
sns.heatmap(data = average_quantity, annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
grouping_price = df4.groupby(['CohortDate', 'CohortIndex'])
cohort_data_price = grouping_price['TotalRevenue'].mean()
cohort_data_price = cohort_data_price.reset_index()
average_price = cohort_data_price.pivot(index='CohortDate',
                                     columns='CohortIndex',
                                     values='TotalRevenue')
average_price.index = average_price.index.strftime('%m-%Y')
average_price
# Out:
# CohortIndex        0          30         60         90         120        150  \
# CohortDate
# 12-2010      20.959735  25.100097  25.342738  25.232395  20.073621  25.661144
# 01-2011      18.643132  23.703978  20.411731  17.662914  21.622991  25.591925
# 02-2011      17.172106  17.182145  19.501224  18.873761  16.141410  15.196536
# 03-2011      17.152927  17.934769  21.550000  17.010363  19.165326  18.126777
# 04-2011      16.450442  20.214846  18.789857  18.441577  18.883195  14.365693
# 05-2011      19.226612  15.905135  21.407534  19.444446  17.917645  14.171812
# 06-2011      16.505256  14.731185  19.066694  19.952438  15.156622  16.126778
# 07-2011      13.226262  21.192895  11.506672  12.592598  10.629563  11.585962
# 08-2011      16.203903  11.940794  11.568374  14.357544  15.627878        NaN
# 09-2011      18.492791  10.536579  13.302208  14.114856        NaN        NaN
# 10-2011      13.236333  10.922911  13.721257        NaN        NaN        NaN
# 11-2011      12.213282  13.178485        NaN        NaN        NaN        NaN
# 12-2011      27.464286        NaN        NaN        NaN        NaN        NaN
#
# CohortIndex        180        210        240        270        300        330  \
# CohortDate
# 12-2010      26.684882  25.579786  26.128374  31.353307  31.003148  22.545412
# 01-2011      24.514303  24.768317  18.797940  20.322813  19.017422  18.804144
# 02-2011      21.670792  21.043878  17.675292  20.821595  21.663756        NaN
# 03-2011      21.795801  17.402673  15.631332  11.658326        NaN        NaN
# 04-2011      14.768816  15.595544  12.042035        NaN        NaN        NaN
# 05-2011      16.332435  13.628026        NaN        NaN        NaN        NaN
# 06-2011      12.833846        NaN        NaN        NaN        NaN        NaN
# 07-2011            NaN        NaN        NaN        NaN        NaN        NaN
# 08-2011            NaN        NaN        NaN        NaN        NaN        NaN
# 09-2011            NaN        NaN        NaN        NaN        NaN        NaN
# 10-2011            NaN        NaN        NaN        NaN        NaN        NaN
# 11-2011            NaN        NaN        NaN        NaN        NaN        NaN
# 12-2011            NaN        NaN        NaN        NaN        NaN        NaN
#
# CohortIndex        360
# CohortDate
# 12-2010      24.887117
# 01-2011            NaN
# 02-2011            NaN
# 03-2011            NaN
# 04-2011            NaN
# 05-2011            NaN
# 06-2011            NaN
# 07-2011            NaN
# 08-2011            NaN
# 09-2011            NaN
# 10-2011            NaN
# 11-2011            NaN
# 12-2011            NaN

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(15, 6))
plt.title('Average Price')
sns.heatmap(data = average_price, annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
